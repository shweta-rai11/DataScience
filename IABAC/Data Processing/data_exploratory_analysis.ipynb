# %% [markdown]
# # DATA EXPLORATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')  # setting up background
from scipy import stats

# TO avoid warnings
import warnings 
warnings.filterwarnings('ignore')

# %%
d1=pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')
d1
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
pd.set_option('display.max_columns',50)

# %%
d1.head(5)
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
d1.tail(5)
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
d1.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
d1.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
d1.tail(5)
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
d1.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %% [markdown]
# # Exploratory data analysis:-
# - Exploratory Data Analysis (EDA) is a process of describing the data by means of statistical and visualization techniques in order to bring important aspects of that data into focus for further analysis. This involves inspecting the dataset from many angles, describing & summarizing it without making any assumptions about its contents.
#
# - It was originally developed by American mathematician John Tukey in the 1970s, EDA techniques continue to be a widely used method in the data discovery process today.
#
# - Exploratory Data Analysis is primarily used to see what data can reveal beyond the formal modeling or hypothesis testing task and provides a provides a better understanding of data set variables and the relationships between them. It can also help determine if the statistical techniques that are considered for data analysis are appropriate.

# %% [markdown]
# ### Numerical features
# - Age
# - DistanceFromHome
# - EmpEducationLevel
# - EmpEnvironmentSatisfaction
# - EmpHourlyRate
# - EmpJobInvolvement
# - EmpJobLevel
# - EmpJobSatisfaction
# - NumCompaniesWorked,
# - EmpLastSalaryHikePercent
# - EmpRelationshipSatisfaction
# - TotalWorkExperienceInYears,
# - TrainingTimesLastYear,
# - EmpWorkLifeBalance
# - ExperienceYearsAtThisCompany
# - ExperienceYearsInCurrentRole
# - YearsSinceLastPromotion
# - YearsWithCurrManager
#
# ### Categorical features
# - Gender
# - EducationBackground
# - MaritalStatus
# - EmpDepartment
# - EmpJobRole
# - BusinessTravelFrequency
# - OverTime
# - Attrition

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS CAN BE FURTHER DIVIDED INTO
# - Univariant analysis
# - Bivariant analysis
# - Multivariant analysis

# %% [markdown]
# # UNIVARIATE ANALYSIS:-
# - Univariate analysis is a form of analysis that only involves a single variable.It means the analysis of a single variable (or column) in a dataset.
# - Univariate analysis is the simplest kind of data analysis in the field of statistics.
# - Univariate analysis explores each variable in a data set, separately. It looks at the range of values, as well as the central tendency of the values. It describes the pattern of response to the variable. It describes each variable on its own.Descriptive statistics describe and summarize data. Univariate descriptive statistics describe individual variables.
# - For better understanding and visualisation of the data the bivariate and the multivariate analysis is used.
#
# ###### VISUALIZATION OF CONTINUOUS FEATURES:-
#
# **continuous features:**- It takes any measured value within a specific range. Continuous features can be visualized using different plot mentioned below.
# - Histogram: A histogram is a graph used to show frequency distribution where data are grouped into continuous ranges and each range corresponds to a vertical bar. The horizontal axis represents the number range while the vertical axis represents the amount of data that is present in a range.
#
# ###### VISUALIZATION OF DISCRETE AND CATEGORICAL FEATURES:-
#
# **Discrete and Categorical:**- Discrete features takes specific countable values. Categorical data is a type of data that is used to group information with similar characteristics.
# -Discrete features can be visualized using different plots mentioned below.
# - Countplot: A Countplot is used to represent the counts of observations in each categorical variables using bars.

# %% [markdown]
# ###  INSIGHTS ON NUMERICAL  FEATURES:-

# %% [markdown]
# - SHOWING ALL THE NUMERICAL FEATURES

# %%
list(d1.select_dtypes('int'))
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmpEducationLevel',
#  'EmpEnvironmentSatisfaction',
#  'EmpHourlyRate',
#  'EmpJobInvolvement',
#  'EmpJobLevel',
#  'EmpJobSatisfaction',
#  'NumCompaniesWorked',
#  'EmpLastSalaryHikePercent',
#  'EmpRelationshipSatisfaction',
#  'TotalWorkExperienceInYears',
#  'TrainingTimesLastYear',
#  'EmpWorkLifeBalance',
#  'ExperienceYearsAtThisCompany',
#  'ExperienceYearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'PerformanceRating']

# %% [markdown]
# # HISTOGRAM
# - A histogram is a graphical representation of data points organized into user-specified ranges. Similar in appearance to a bar graph, the histogram condenses a data series into an easily interpreted visual by taking many data points and grouping them into logical ranges or bins.
# - Histogram is created using a for loop for better visualisation.

# %% [markdown]
# **Subplots is used to visualize the numerical features.**

# %%
count = d1[['Age','DistanceFromHome','EmpEducationLevel','EmpEnvironmentSatisfaction','EmpHourlyRate','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction','NumCompaniesWorked','EmpLastSalaryHikePercent','EmpRelationshipSatisfaction','TotalWorkExperienceInYears','TrainingTimesLastYear','EmpWorkLifeBalance','ExperienceYearsAtThisCompany','ExperienceYearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','PerformanceRating']] # making lsit of 19 features
# defining canvas size
plt.figure(figsize=(15,20))
plotno = 1 # counter

for column in count: # iteration of columns / acessing the columns from count 
    if plotno<=20:    # set the limit
        plt.subplot(5,4,plotno) # # plotting 20 graphs (5-rows,4-columns) ,plotnumber is for count
        sns.histplot(x=count[column],color = "purple", ec="white") # Plotting Histplots because the feature data type numerical
        plt.xlabel(column,fontsize=19)  # assigning name to x-axis and font size is 19
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# **INSIGHTS**
#
#  **Age**
# - The overall range is between 18 and 60years.
# - The employees maximum age is between the age group of 25 to 40years.
#
# **DistanceFromHome**
# - The overall range is between 0 to 30.
# - The minimum range of the employee's DistanceFromHome is 10-30.
# - The maximum range of the employee's DistanceFromHome is 0 to 8.
#
# **EmpEducationLevel**
# - The overall range is between 1 to 5
# - The employee's minimum EmpEducationLevel is 5.0
# - The employee's maximum EmpEducationLevel is 1.0
#
# **EmpEnvironmentSatisfaction**
# - The overall range is between 1 to 4
# - The employee's minimum EmpEnvironmentSatisfaction is 1.0
# - The employee's maximum EmpEnvironmentSatisfaction is 3.0
#
# **EmpHourlyRate**
# - The overall range is between 30 to 100
# - The employee's minimum EmpHourlyRate range is between 30 to 40
# - The employee's maximum EmpHourlyRate range is between 40 to 50
#
# **EmpJobInvolvement**
# - The overall range is between 1 to 4
# - The employee's minimum EmpJobInvolvement is 1
# - The employee's maximum EmpJobInvolvement is 3
#
# **EmpJobLevel**
# - The overall range is between 1 to 5
# - The employee's minimum EmpJobLevel is 5
# - The employee's maximum EmpJobLevel is 1
#
# **EmpJobSatisfaction**
# - The overall range is between 1 to 4
# - The employee's minimum EmpJobSatisfaction is 1
# - The employee's maximum EmpJobSatisfaction is 4
#
# **NumCompaniesWorked**
# - The overall range is between 0 to 5
# - The employee's number of companies worked is minimum at 8
# - The employee's number of companies worked is maximum at 1
#
# **EmpLastSalaryHikePercent**
# - The overall range is between 0 to 25
# - The employee's last salary hike percent is minimum at the range 22 to 23
# - The employee's last salary hike percent is maximum at the range 12 to 14
#
# **EmpRelationshipSatisfaction**
# - The overall range is between 1 to 4
# - The employee's relationship satisfaction is minimum at 1
# - The employee's relationship satisfaction is maximum at 3
#
# **TotalWorkExperienceInYears**
# - The overall range is between 0 to 40
# - The employee's total work experience in years is minimum around 15 to 40
# - The employee's total work experience in years is maximum around 5 to 10
#
# **TrainingTimesLastYear**
# - The overall range is between 0 to 6
# - The employee's training times last year is minimum at 0
# - The employee's training times last year is maximum at 2
#
# **EmpWorkLifeBalance**
# - The overall range is between 1 to 4
# - The employee's work life balance is minimum at 1.0
# - The employee's work life balance is maximum at 3.0
#
# **ExperienceYearsAtThisCompany**
# - The overall range is between 0 to 40
# - The employee's experience years at this company is minimum around 10 to 40
# - The employee's experience years at this company is maximum around 0 to 10
#
# **ExperienceYearsInCurrentRole**
# - The overall range is between 0 to 17.5
# - The employee's experience years in current role is minimum around 10 to 17.5
# - The employee's experience years in current role is maximum around 0 to 7.5
#
# **YearsSinceLastPromotion**
# - The overall range is between 0 to 15
# - The employee's years since last promotion is minimum 14
# - The employee's years since last promotion is maximum 0
#
# **YearsWithCurrManager**
# - The overall range is between 0 to 17.5
# - The employee's years with current Manager is minimum 10.0 to 17.5
# - The employee's years with current Manager is maximum 0.0 to 2.5
#
# **PerformanceRating**
# - This feature is the target feature.
# - The employee's performance rating is minimum at 4.00
# - The employee's performance rating is maximum at 3.00

# %% [markdown]
# #  INSIGHTS ON CATEGORICAL  FEATURES:-

# %% [markdown]
# - SHOWING ALL THE CATEGORICAL FEATURES

# %%
list(d1.select_dtypes('object'))
# Out:
# ['EmpNumber',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'OverTime',
#  'Attrition']

# %% [markdown]
# # COUNTPLOT

# %% [markdown]
# - A count plot is similar to a bar plot and a histogram but it provides counts of categorical values.
# - The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable

# %% [markdown]
# ### VISUALIZATION OF CATEGORICAL FEATURES:-
# - USING SUBPLOT TO PLOTS MULTIPLE FEATURE

# %%
categorical = d1[[
 'Gender',
 'EducationBackground',
 'MaritalStatus',
 'EmpDepartment',
 'BusinessTravelFrequency',
 'OverTime',
 'Attrition']] # making lsit of next 9 feature

plt.figure(figsize=(15,20)) # defining canvas size
plotno = 1 # counter

for column in categorical: # iteration of columns / acessing the columns from count 
    if plotno<=8:    # set the limit
        plt.subplot(4,2,plotno) # # plotting 8 graphs (4-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=categorical[column], palette='nipy_spectral_r') # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# **INSIGHTS:**
#
# **Gender:**
# - The male count is above 700 while female count is below 500
# - The male employees count is higher than the female count.
#
# **EducationBackground**
# - The EducationBackground life science has higher counts followed by medical.
# - The EducationBackground Human Resources department has the least counts.
#
# **MaritalStatus**
# - The employee's with MaritalStatus married is maximum followed by single.
# - The employee's with MaritalStatus divorced is minimum.
#
# **EmpDepartment**
# - The counts of sales EmpDepartment, development EmpDepartment and research and development has almost the highest counts.
# - The EmpDepartment which has the least count is the Data Science department.
#
# **Business Travel Frequency**
# - The employees Business Travel Frequency who travel rarely is the maximum.
# - The employees Business Travel Frequency who don't travel is the minimum.

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpJobRole',data=d1)
plt.xlabel('EmpJobRole',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
# - The job role sales executive has the maximum counts followed by developer, Manager R&D, Research scientist.
# - The job role Technical Architect has the minimum counts.

# %% [markdown]
# # BIAVARIATE ANALYSIS
#
# - Bivariate analysis is one of the simplest forms of quantitative (statistical) analysis. It involves the analysis of two variables (often denoted as X, Y), for the purpose of determining the empirical relationship between them.
# - In order words, it is meant to determine any concurrent relationship between different variables and finally to extract relevant relationships for better understanding of the data

# %% [markdown]
# ### BARPLOT
# - A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.
#
# ### Lineplot
# - A line plot is a type of plot in Seaborn that shows the relationship between two continuous variables by connecting the data points with a straight line.

# %% [markdown]
# # INSIGHTS ON CONTINUOUS FEATURES WITH CONTINUOUS FEATURES:-

# %% [markdown]
# **Lineplot is used to understand the relationship between the continuous feature and continuous feature**

# %% [markdown]
# **Relationship between Age and EmpEducationLevel****

# %%
sns.lineplot(x='EmpEducationLevel',y='Age',data=d1,color='green')
plt.xlabel('EmpEducationLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employees age is 40 and above, the employees education level is 5.0
# - when the employees age is around 36 to 38, the employees education level is 2.0
# - when the employees age is around 38 to 40, the employees education level is 4.0

# %% [markdown]
# **Relationship between NumCompaniesWorked and EmpJobLevel**

# %%
sns.lineplot(x='NumCompaniesWorked',y='EmpJobLevel',data=d1,color='red')
plt.xlabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee job level is 1.8 i.e minimum, the employees worked in nearly 1.
# - when the employee job level is above 2.4 i.e maximum, the employees worked in nearly 3.

# %% [markdown]
# **Relationship between EmpLastSalaryHikePercent  and EmpJobLevel****

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='EmpJobLevel',data=d1,color='blue')
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee job level is 2.4, the employees last salary hike percent is 2.4
# - when the employee job level is above 1.6 and below 1.8 i.e minimum, the employees last salary hike percent is 2.0
# - when the employee job level is above 2.2, the employees last salary hike percent is 2.2

# %% [markdown]
# **Relationship between TotalWorkExperienceInYears   and PerformanceRating**

# %%
sns.lineplot(x='TotalWorkExperienceInYears',y='PerformanceRating',data=d1,color='purple')
plt.xlabel('TotalWorkExperienceInYears',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the total work experience in years is 35 to 40 the performance rating is above 2.25 and below 2.50
# - when the total work experience in years is 0 to 2 the performance rating is above 3.00 and below 3.25

# %% [markdown]
# **Relationship between TotalWorkExperienceInYears   and YearsSinceLastPromotion**

# %%
sns.lineplot(x='TotalWorkExperienceInYears',y='YearsSinceLastPromotion',data=d1,color='black')
plt.xlabel('TotalWorkExperienceInYears',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the total work experience in years is between 0 to 15, the years since last promotion is between 0 to 4.
# - when the total work experience in years is between 35 to 40, the years since last promotion is above 14.

# %% [markdown]
# **Relationship between ExperienceYearsInCurrentRole  and ExperienceYearsAtThisCompany**

# %%
sns.lineplot(x='ExperienceYearsInCurrentRole',y='ExperienceYearsAtThisCompany',data=d1,color='yellow')
plt.xlabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The experience years in current role between 0.0 to 5.0, the experience years at this company is 0 to 10.
# - The experience years in current role between 5.0 to 7.5, the experience years at this company is above 15.
# - The experience years in current role between 10.0 to 15.0, the experience years at this company is 20.
# - The experience years in current role between 15.0 to 17.5, the experience years at this company is above 25.

# %% [markdown]
# **Relationship between YearsSinceLastPromotion  and 	YearsWithCurrManager**

# %%
sns.lineplot(x='YearsSinceLastPromotion',y='YearsWithCurrManager',data=d1,color='orange')
plt.xlabel('YearsSinceLastPromotion',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the years since last promotion is 1, the years with current manager is 4.
# - when the years since last promotion is 2 to 10 years the years with current manager is between 6 to 8.
# - when the years since last promotion is 12 to 14 years, the years with current manager is between 8 to 10

# %% [markdown]
# **Relationship between EmpLastSalaryHikePercent and 	TotalWorkExperienceInYears**

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='TotalWorkExperienceInYears',data=d1,color='brown')
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee last salary hike percent is between 12 to 22, the total work experience in years is between 10-12 years.
# - when the employee last salary hike percent is between 22 to 24, the total work experience in years is between 12-14 and above.

# %% [markdown]
# **Relationship between EmpLastSalaryHikePercent and 	NumCompaniesWorked**

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='NumCompaniesWorked',data=d1,color='violet')
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee salary hike percent is between 12 to 24, the employees worked in the number of companies is between 2.5 to 3.0
# - when the employee salary hike percent is 24 and above, the employees worked in the number of companies is decreased to 1.5

# %% [markdown]
# **Relationship between EmpLastSalaryHikePercent and 	ExperienceYearsInCurrentRole**

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='ExperienceYearsInCurrentRole',data=d1,color='maroon')
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee last salary hike percent is between 12 to 22, the experience years in current role is 4 to 5.
# - when the employee last salary hike percent is more than 23, the experience years in current role is above 6 and below 7.
# - when the employee last salary hike percent is more than 24, the experience years in current role is nearly 7.

# %% [markdown]
# **Relationship between EmpEnvironmentSatisfaction and EmpJobLevel**

# %%
sns.barplot(x='EmpEnvironmentSatisfaction',y='EmpJobLevel',data=d1, palette='autumn_r')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the employee job level is more than 2.0, the employee environment satisfaction is 1.
# - when the employee job level is 2.0, the employee environment satisfaction is 2.
# - when the employee job level is more than 2.0, the employee environment satisfaction is 3.
# - when the employee job level is more than 2.0, the employee environment satisfaction is 4.

# %% [markdown]
# # INSIGHTS ON CATEGORICAL FEATURES WITH NUMERICAL FEATURES:-

# %% [markdown]
# **Relationship between Gender and TotalWorkExperienceInYears**

# %%
sns.barplot(x='Gender',y='TotalWorkExperienceInYears',data=d1, palette='twilight_shifted')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The TotalWorkExperienceInYears at this company of the male employees are above 10 and less than 12
# - The TotalWorkExperienceInYears at this company of the female employees are nearly 12.
# - The female employees TotalWorkExperienceInYears is higher than that of the male employees

# %% [markdown]
# **Relationship between Age and Gender**

# %%
sns.barplot(x='Gender',y='Age',data=d1, palette='seismic')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The maximum age for the female employees are around 35-40 years
# - The maximum age for the male employees are around 35-38 years

# %% [markdown]
# **Relationship between EmpEducationLevel  and EducationBackground**

# %%
sns.barplot(x='EmpEducationLevel',y='EmpDepartment',data=d1, palette='Accent')
plt.xlabel('EmpEducationLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The EmpDepartment Finance has the highest counts for EmpEducationLevel.
# - The EmpDepartment Data Science has the lowest counts for EmpEducationLevel.
# - The Employees education level of the employees from the Human Resources is 3.0
# - The Employees education level of the employees from the Development is above 2.5 and below 3.0
# - The Employees education level of the employees from Data Science is above 2.5 and below 3.0
# - The Employees education level of the employees from the Research and development is above 2.5 and below 3.0
# - The Employees education level of the employees from the Finance is above 3.0

# %% [markdown]
# **Relationship between performance rating and EducationBackground**

# %%
sns.barplot(x='PerformanceRating',y='EmpDepartment',data=d1,palette='Accent_r')
plt.xlabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The PerformanceRating of the employees from sales department is below 3.0
# - The PerformanceRating of the employees from the Human Resources is below 3.0
# - The PerformanceRating of the employees from the Development is above 3.0
# - The PerformanceRating of the employees from Data Science is above 3.0
# - The PerformanceRating of the employees from the Research and development is below 3.0
# - The PerformanceRating of the employees from the Finance is below 3.0

# %% [markdown]
# **Relationship between EmpDepartment  and 	EmpEnvironmentSatisfaction**

# %%
sns.barplot(x='EmpEnvironmentSatisfaction',y='EmpDepartment',data=d1,palette='Blues_r')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The EmpDepartment Sales and Human Resources has the minimum EmpEnvironmentSatisfaction.
# - The EmpDepartment Data Science has the maximum EmpEnvironmentSatisfaction.

# %% [markdown]
# **Relationship between EmpJobRole and EmpEnvironmentSatisfaction**

# %%
sns.barplot(x='EmpEnvironmentSatisfaction',y='EmpJobRole',data=d1, palette='rocket_r')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=18)
plt.show()

# %% [markdown]
# **Observation:**
# - Delivery Manager,Technical Architech,Manufacturing director has the EmpEnvironmentSatisfaction above 3.0
# - Almost all the EmpJobRole has the EmpEnvironmentSatisfaction of above 2.5 except for Business Analyst.
# - Business analyst has the minimum EmpEnvironmentSatisfaction.

# %% [markdown]
# **Relationship between EmpJobLevel  and MaritalStatus**

# %%
sns.barplot(x='EmpJobLevel',y='MaritalStatus',data=d1,palette='terrain_r')
plt.xlabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The divorced and married MaritalStatus has EmpJobLevel more than 2.0
# - The single MaritalStatus has EmpJobLevel more than 1.5 but less than 2.0

# %% [markdown]
# **Relationship between EducationBackground and NumCompaniesWorked**

# %%
sns.barplot(x='NumCompaniesWorked',y='EducationBackground',data=d1, palette='PiYG')
plt.xlabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The EducationBackground Human Resource has worked in more 3 companies.
# - The EducationBackground in other background has worked in less than 3 companies but more than 2 companies.

# %% [markdown]
# **Relationship between BusinessTravelFrequency and 	EmpEducationLevel**

# %%
sns.barplot(x='BusinessTravelFrequency',y='EmpEducationLevel',data=d1, palette='Wistia')
plt.xlabel('BusinessTravelFrequency',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The BusinessTravelFrequency Travel_rarely, Travel_frequently and Non-travel has almost same EmpEducationLevel more tahn 2.5 and less than 3.0.

# %% [markdown]
# **10) Relationship between 	EmpJobRole and EmpJobLevel**

# %%
sns.barplot(x='EmpJobLevel',y='EmpJobRole',data=d1,palette='Set2_r')
plt.xlabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpJobLevel Manager has EmpJobRole more than 4.
# - EmpJobLevel Research Director is more than 3 but less than 4
# - EmpJobLevel Sales Representative has least EmpJobLevel i.e 1

# %% [markdown]
# **Relationship between EducationBackground and EmpJobInvolvement**

# %%
sns.barplot(x='EmpJobInvolvement',y='EducationBackground',data=d1, palette='gist_stern')
plt.xlabel('EmpJobInvolvement',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EducationBackground Human Resources has the maximum EmpJobInvolvement.
# - EducationBackground Technical degree and other has the minimum EmpJobInvolvement.

# %% [markdown]
# **Relationship between MaritalStatus and EmpWorkLifeBalance**

# %%
sns.barplot(x='MaritalStatus',y='EmpWorkLifeBalance',data=d1, palette='coolwarm_r')
plt.xlabel('MaritalStatus',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - MaritalStatus single,married,divorced has almost same EmpWorkLifeBalance i.e above 2.5

# %% [markdown]
# **Relationship between EmpRelationshipSatisfaction and MaritalStatus**

# %%
sns.barplot(x='MaritalStatus',y='EmpRelationshipSatisfaction',data=d1, palette='icefire')
plt.xlabel('MaritalStatus',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpRelationshipSatisfaction is maximum in MaritalStatus single followed by the divorced employees.
# - EmpRelationshipSatisfaction is minimum in married employees.

# %% [markdown]
# **17) Relationship between ExperienceYearsInCurrentRole  and EmpJobRole**

# %%
sns.barplot(x='ExperienceYearsInCurrentRole',y='EmpJobRole',data=d1, palette='gnuplot_r')
plt.xlabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpJobRole Manager has the maximum ExperienceYearsInCurrentRole i.e above 6
# - EmpJobRole Research Director also has the ExperienceYearsInCurrentRole above 6
# - EmpJobRole Technical Architect has the minimum ExperienceYearsInCurrentRole

# %% [markdown]
# **16) Relationship between NumCompaniesWorked and Gender**

# %%
sns.barplot(x='Gender',y='NumCompaniesWorked',data=d1, palette='rocket')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Gender females has worked in more than 2.5 NumCompaniesWorked
# - The females has worked in more companies than the male employees,

# %% [markdown]
# **18) Relationship between ExperienceYearsInCurrentRole  and EmpDepartment**

# %%
sns.barplot(x='ExperienceYearsInCurrentRole',y='EmpDepartment',data=d1, palette='twilight_shifted_r')
plt.xlabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpDepartment sales and finance has employees with the highest ExperienceYearsInCurrentRole
# - EmpDepartment Data science employees has employees with lowest ExperienceYearsInCurrentRole

# %% [markdown]
# **19) Relationship between BusinessTravelFrequency  and NumCompaniesWorked**

# %%
sns.barplot(x='BusinessTravelFrequency',y='NumCompaniesWorked',data=d1, palette='Pastel2')
plt.xlabel('BusinessTravelFrequency',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - BusinessTravelFrequency who travel rarely and non-traveller have worked on more than 2.5 NumCompaniesWorked
# - BusinessTravelFrequency who travel less frequently has worked on 2.5 NumCompaniesWorked

# %% [markdown]
# **21) Relationship between YearsSinceLastPromotion  and Attrition**

# %%
sns.barplot(x='Attrition',y='YearsSinceLastPromotion',data=d1, palette='Purples_r')
plt.xlabel('Attrition',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees who have received YearsSinceLastPromotion more than 2.0, the employees are not leaving the company.
# - The employees who have received YearsSinceLastPromotion less than 2.0, the employees are leaving the company.

# %% [markdown]
# **20) Relationship between EmpHourlyRate and OverTime**

# %%
sns.barplot(x='OverTime',y='EmpHourlyRate',data=d1, palette='tab20b_r')
plt.xlabel('OverTime',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpHourlyRate for those who are into overtime and those who are not into overtime are almost same.

# %% [markdown]
# **22) Relationship between PerformanceRating  and OverTime**

# %%
sns.barplot(x='PerformanceRating',y='OverTime',data=d1, palette='GnBu')
plt.xlabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - PerformanceRating of the employees who are doing overtime are higher than the employees who are not doing overtime.

# %% [markdown]
# **24) Relationship between gender and EmpWorkLifeBalance**

# %%
sns.barplot(x='Gender',y='EmpWorkLifeBalance',data=d1, palette='ocean_r')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The EmpWorkLifeBalance of both the genders are almost the same.

# %% [markdown]
# **23) Relationship between EmpJobSatisfaction  and OverTime**

# %%
sns.barplot(x='EmpJobSatisfaction',y='OverTime',data=d1,palette='viridis_r')
plt.xlabel('EmpJobSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpJobSatisfaction who does overtime and who doesn't do overtime are almost the same.

# %% [markdown]
# # BIVARIANT ANALYSIS OF CATEGORICAL FEATURES WITH GENDER
# - USING SUBPLOT TO PLOTS MULTIPLE FEATURES

# %%
# Make a list of categorical feature and use sub plot to plot multiple feature
col = d1[['EducationBackground','MaritalStatus','EmpDepartment','BusinessTravelFrequency','OverTime','Attrition']]
plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in col: # iteration of columns / acessing the columns from count 
    if plotno<=8:    # set the limit
        plt.subplot(4,2,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=col[column],hue=d1.Gender, palette='gist_rainbow') # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# **Observation:**
#
# **EducationBackground:**
# - EducationBackground marketing has the male and female employees almost the same.
# - EducationBackground Life Sciences has higher male employees than female employees.
# - EducationBackground Human resources has the male and female employees ratio almost the same.
# - EducationBackground medical has the male employees higher than the female employees.
# - EducationBackground technical degree has the male employees higher than the female employees.
#
# **MaritalStatus**
# - The number of single males employees are higher than the female employees.
# - The number of married males are higher than the married female employees.
# - The number of divorced males are higher than the female employees.
#
# **EmpDepartment**
# - EmpDepartment sales, has the maximum number of males than the female employees.The female employees count is nearly 150 while in case of male employees count it is above 200.
# - EmpDepartment Human resources has the ratio of male and female employees almost the same.
# - EmpDepartment development,has the maximum number of males than the female employees, the female employees count is below 150 while the male employees count is above 200.
# - In Data science,the ratio of male and female employees are almost the same.
# - In research and development, the female employees count is above 100 and below 150 while the male employees count is above 200.
# - In Finance, the ratio of male and female employees are almost the same.
#
# **BusinessTravelFrequency**
# - The BusinessTravelFrequency travels rarely has more male counts than the female.The males travel rarely than the females.
# - The female and male employees almost travel frequently.
# - The count for male employee non-traveler is higher than the female.
#
# **OverTime**
# - The ratio of male and female employees doing overtime is almost the same.
#
# **Attrition**
# - The female employees are less probable to leave the job.
# - The male employees are more frequent to leave the job.

# %% [markdown]
# **5) Relationship between EmpDepartment  and 	EmpEnvironmentSatisfaction**

# %%
sns.barplot(x='EmpEnvironmentSatisfaction',y='EmpDepartment',data=d1,palette='RdBu')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employee's environment satisfaction is higher in Data Science followed by Finance and research and development.
# - The employee's environment satisfaction is lower in Human Resources.

# %% [markdown]
# **5) Relationship between EmpJobLevel  and 	MaritalStatus**

# %%
sns.barplot(x='EmpJobLevel',y='MaritalStatus',data=d1, palette='Purples_r')
plt.xlabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when the Employees job level is above 2.0, the marital status can either be Married or Divorced.

# %% [markdown]
# **6) Relationship between EmpJobRole and EmpEnvironmentSatisfaction**

# %%
sns.barplot(x='EmpEnvironmentSatisfaction',y='EmpJobRole',data=d1, palette='rocket')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Technical Architech has the highest environment satisfaction.
# - Business Analyst has the lowest envirnoment satisfaction.

# %% [markdown]
# **8) Relationship between BusinessTravelFrequency and 	EmpEducationLevel**

# %%
sns.barplot(x='BusinessTravelFrequency',y='EmpEducationLevel',data=d1, palette='PuRd_r')
plt.xlabel('BusinessTravelFrequency',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employee's travelling rarely, travelling frequently and non traveller has education level more than 2.5 and less than 3.0

# %% [markdown]
# **9) Relationship between NumCompaniesWorked and 	EducationBackground**

# %%
sns.barplot(x='NumCompaniesWorked',y='EducationBackground',data=d1, palette='Oranges')
plt.xlabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees working in the Human resources educational background has worked in more than 3 companies.
# - The employees working in the other educational background has worked in more than 2 companies but less than 3 companies.

# %% [markdown]
# **10) Relationship between 	EmpJobRole and EmpJobLevel**

# %%
sns.barplot(x='EmpJobLevel',y='EmpJobRole',data=d1, palette='nipy_spectral_r')
plt.xlabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The Employees job level is more than 4 when the employee's job role is Manager.
# - The Employees job level is more than 3 when the employee's job role is Research Director.
# - The Employees job level is nearly 1 and the least when the employee's job role is Sales Representative.

# %% [markdown]
# **12) Relationship between MaritalStatus and EmpWorkLifeBalance**

# %%
sns.barplot(x='MaritalStatus',y='EmpWorkLifeBalance',data=d1, palette='nipy_spectral_r')
plt.xlabel('MaritalStatus',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The single,married,divorced marital status has same employee work life balance.

# %% [markdown]
# **13) Relationship between EducationBackground and EmpJobInvolvement**

# %%
sns.barplot(x='EmpJobInvolvement',y='EducationBackground',data=d1, palette='gist_yarg')
plt.xlabel('EmpJobInvolvement',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The Human Resources has the highest Employee job involvement.
# - Technical degree and other has the lowest Employee job involvement.

# %% [markdown]
# **15) Relationship between EmpRelationshipSatisfaction and MaritalStatus**

# %%
sns.barplot(x='MaritalStatus',y='EmpRelationshipSatisfaction',data=d1, palette='rocket')
plt.xlabel('MaritalStatus',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The Employee Relationship satisfaction is higher in single employees followed by the divorced employees.
# - The Employee Relationship satisfaction is lowest in married employees.

# %% [markdown]
# **16) Relationship between NumCompaniesWorked and Gender**

# %%
sns.barplot(x='Gender',y='NumCompaniesWorked',data=d1, palette='Accent_r')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The female employees has worked in more companies than the male employees

# %% [markdown]
# **17) Relationship between ExperienceYearsInCurrentRole  and EmpJobRole**

# %%
sns.barplot(x='ExperienceYearsInCurrentRole',y='EmpJobRole',data=d1, palette='Accent_r')
plt.xlabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees job role Manager has the highest experience years in current role followed by Research Director.
# - Technical Architect has the lowest experience years in current role.

# %% [markdown]
# **18) Relationship between ExperienceYearsInCurrentRole  and EmpDepartment**

# %%
sns.barplot(x='ExperienceYearsInCurrentRole',y='EmpDepartment',data=d1, palette='CMRmap_r')
plt.xlabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Both sales and finance employees has the highest experience years in current role.
# - Data science employees has the lowest experience years in current role.

# %% [markdown]
# **19) Relationship between BusinessTravelFrequency  and NumCompaniesWorked**

# %%
sns.barplot(x='BusinessTravelFrequency',y='NumCompaniesWorked',data=d1, palette='rocket')
plt.xlabel('BusinessTravelFrequency',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees who travel rarely and non-traveller have worked on more than 2.5
# - The employees who travel less frequently has worked on 2.5

# %% [markdown]
# **20) Relationship between EmpHourlyRate and OverTime**

# %%
sns.barplot(x='OverTime',y='EmpHourlyRate',data=d1, palette='Wistia_r')
plt.xlabel('OverTime',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees hourly rate for those who do overtime and those who don't do overtime are almost same.

# %% [markdown]
# **21) Relationship between YearsSinceLastPromotion  and Attrition**

# %%
sns.barplot(x='Attrition',y='YearsSinceLastPromotion',data=d1, palette='rocket')
plt.xlabel('Attrition',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - When the employees have received years since last promotion more than 2.0, the employees are not leaving the company.
# - when the employees have received years since last promotion less than 2.0, the employees are leaving the company.

# %% [markdown]
# **22) Relationship between PerformanceRating  and OverTime**

# %%
sns.barplot(x='PerformanceRating',y='OverTime',data=d1, palette='Dark2')
plt.xlabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The performance rating of the employees who does overtime and who doesn't undergo overtime are almost the same.

# %% [markdown]
# **23) Relationship between EmpJobSatisfaction  and OverTime**

# %%
sns.barplot(x='EmpJobSatisfaction',y='OverTime',data=d1, palette='YlOrBr')
plt.xlabel('EmpJobSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The employees job satisfaction of the employees who does overtime and who doesn't undergo overtime are almost the same.

# %% [markdown]
# **24) Relationship between gender and EmpWorkLifeBalance**

# %%
sns.barplot(x='Gender',y='EmpWorkLifeBalance',data=d1, palette='rocket')
plt.xlabel('Gender',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The male and female employees work life balance are almost same for both the gender.

# %% [markdown]
# # MULTIVARIANT ANALYSIS:-
#
# - Multiple regression is the most commonly utilized multivariate technique. It examines the relationship between a single metric dependent variable and two or more metric independent variables.

# %% [markdown]
# # MULTIVARIANT ANALYSIS OF CATEGORICAL FEATURES WITH performance rating
# - USING SUBPLOT TO PLOTS MULTIPLE FEATURES

# %%
numerical = d1[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction','EmpRelationshipSatisfaction','TrainingTimesLastYear','EmpWorkLifeBalance']]

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in numerical: # iteration of columns / acessing the columns from count 
    if plotno<=18:    # set the limit
        plt.subplot(3,6,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=numerical[column],hue=d1.PerformanceRating, palette='rocket') # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
        plt.ylabel('PerformanceRating')
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# **OBSERVATION**

# %% [markdown]
# **EmpEducationLevel:**
# - The employee's education level at 5 is the minimum.
# - The employee's education level at 3 and performance rating 3 is the maximum.
#
# **EmpEnvironmentSatisfaction:**
# - EmpEnvironmentSatisfaction was 1 and 2 , the count of performance rating at 2 was maximum than   the EmpEnvironmentSatisfaction at 3 and 4.
# - EmpEnvironmentSatisfaction was 3 and 4, the count of performance rating at 3 was maximum.
#
# **EmpJobInvolvement:**
# - EmpJobInvolvement is 3 the count of  performance rating is 3.
#
# **EmpJobLevel:**
# - EmpJobLevel is 1 and 2, the count of performance rating is 3.
#
# **EmpJobSatisfaction:**
# - EmpJobSatisfaction is 4, the count of performance rating is 3.
#
# **EmpRelationshipSatisfaction:**
# - EmpRelationshipSatisfaction is 3, the count of performance rating is 3.
#
# **TrainingTimeLastYear:**
# - TrainingTimeLastYear is 2, the count of performance rating is 3.
#
# **EmpWorkLifeBalance:**
# - EmpWorkLifeBalance is 3, the count of performance rating is 3.
#
# **From the above graph it is indicated that the performance rating 3 has the highest occurance**

# %% [markdown]
# **Relationship between EmpDepartment and OverTime with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpDepartment',y='EmpJobLevel',hue=d1.PerformanceRating,data=d1, palette='Set2_r')
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - In Data science department it has EmpJobLevel of 5 at the performance rating of 2
# - In Sales department, when the performance rating is 2,3 and 4 the EmpJobLevel is between 2 and 3.
# - In Research & development department, when the performance rating is 2,3 and 4 the EmpJobLevel is all same that is 2. This means in this department the ratio of high performance and low performance are equal.

# %% [markdown]
# **Relationship between MaritalStatus and EmpLastSalaryHikePercent with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='MaritalStatus',y='EmpLastSalaryHikePercent',hue=d1.PerformanceRating,data=d1, palette='Spectral')
plt.xlabel('MaritalStatus',fontsize=20)
plt.ylabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - In Single MaritalStatus, The performance rating 4 is the maximum.
# - In Married MaritalStatus, the performance rating 4 is the maximum.
# - In divorced MaritalStatus, the performance rating 4 is the maximum.

# %% [markdown]
# **5) Relationship between Attrition and YearsWithCurrManager with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='YearsWithCurrManager',hue=d1.PerformanceRating,data=d1, palette='gist_rainbow')
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('YearsWithCurrManager',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when YearsWithCurrManager increases than performance rating is 2 and chances of employee to leave the company is almost the same.
# - when the employee perfomance rating is 4 and current manager year is increases in that case most of the employee doesn't leave the company.

# %% [markdown]
# **5) Relationship between EmpEnvironmentSatisfaction and BusinessTravelFrequency with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpEnvironmentSatisfaction',y='BusinessTravelFrequency',hue=d1.PerformanceRating,data=d1, palette='YlOrRd')
plt.xlabel('EmpEnvironmentSatisfaction',fontsize=20)
plt.ylabel('BusinessTravelFrequency',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - EmpEnvironmentSatisfaction maximum has performance rating 3 & 4 in BusinessTravelFrequency
# - EmpEnvironmentSatisfaction minimum has performance rating 2 in BusinessTravelFrequency
# - The performance rating 3 and 4 has the highest counts among all.

# %% [markdown]
# **5) Relationship between OverTime and  DistanceFromHome with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='OverTime',y='DistanceFromHome',hue=d1.PerformanceRating,data=d1, palette='Accent')
plt.xlabel('OverTime',fontsize=20)
plt.ylabel('DistanceFromHome',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# - when the distance from home increses the performance rating is constant with employee doing overtime as well as not doing overtime.

# %% [markdown]
# **5) Relationship between Attrition and NumCompaniesWorked with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='NumCompaniesWorked',hue=d1.PerformanceRating,data=d1, palette='Wistia_r')
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# - when the distance from home increses than the performance rating is constant with employee doing overtime as well as not doing overtime.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Gender',y='NumCompaniesWorked',hue=d1.PerformanceRating,data=d1, palette='copper_r')
plt.xlabel('Gender',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Male employee having 2.5 number companies worked has performance rating of 3, the female employee having more than 2.5 number companies worked has performance rating of 3
# - Male employee having more than 2.5 and less than 3.0 number companies worked has performance rating of 2 and 4.
# - Female employee having more than 2.0 and less than 3.0 number companies worked has performance rating of 2 and 4.

# %% [markdown]
# **5) Relationship between EmpJobLevel and OverTime with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpJobLevel',y='OverTime',hue=d1.PerformanceRating,data=d1, palette='BuGn_r')
plt.xlabel('EmpJobLevel',fontsize=20)
plt.ylabel('OverTime',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Employee job level is 2.0, the employee has overtime then the performance rating is 4.
#
# - Employee job level is 2.0, the employee doesn't have overtime then the performance rating is 4.
#
# - Employee job level is more than 2.0, the employee has overtime then the performance rating is 3.
#
# - when the employee job level is more than 2.0 and less than 2.5, the employee doesn't have overtime then the performance rating is 2.
#
# - when the employee job level is more than 2.0 and less than 2.5, the employee has overtime then the performance rating is 2.
#
# - when the employee job level is less than 2.0, the employee doesn't have overtime then the performance rating is 3.

# %% [markdown]
# **5) Relationship between EmpDepartment and OverTime with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpDepartment',y='EmpJobLevel',hue=d1.PerformanceRating,data=d1, palette='Blues')
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('EmpJobLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - Data science department has employee job level of 5 when the performance rating is 2 i.e the maximum.
# - Sales department and has employee job level of more than 2 when the performance rating is 2 and 4.
# - Research and development has EmpJobLevel of 2 when the performance rating is 2, 3 and 4

# %% [markdown]
# - Scatterplot ( Numerical-Numerical)
# - Lineplot (Numerical-Numerical)

# %% [markdown]
# ### Using Pie-chart to show the department distribution in the organization

# %% [markdown]
# - A pie chart is a pictorial representation of data in the form of a circular chart or pie where the slices of the pie show the size of the data.

# %%
# Set the figure size
plt.figure(figsize=(10,15))
Employee_department_counts = d1['EmpDepartment'].value_counts()
plt.pie(Employee_department_counts,labels=Employee_department_counts.index, autopct='%1.1f%%', explode=[0.1]*len(Employee_department_counts))
# Set the title of the pie chart
plt.title('Employee department distribution')
# Display the pie chart
plt.show()

# %% [markdown]
# **Observation**:

# %% [markdown]
# - Data Science has the lowest count
# - Sales has the highest count

# %% [markdown]
# **Relationship between Age and EmpEducationLevel with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age',y='EmpEducationLevel',hue=d1.PerformanceRating,data=d1, palette='magma_r')
plt.xlabel('Age',fontsize=20)
plt.ylabel('EmpEducationLevel',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - when performance rating is 2 and 4, the lowest EmpEducationLevel is 1 and thee age is around 23 and above.
# - while when the performance rating is 3, the lowest EmpEducationLevel is 1.5 and above and the age is around 21.
# - when the age is between 40 and 50, the performance rating is 2,3,4 the highest EmpEducationLevel IS 4

# %% [markdown]
# **Relationship between TotalWorkExperienceInYears and 	ExperienceYearsInCurrentRole with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='TotalWorkExperienceInYears',y='ExperienceYearsInCurrentRole',hue=d1.PerformanceRating,data=d1, palette='crest')
plt.xlabel('TotalWorkExperienceInYears',fontsize=20)
plt.ylabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The TotalWorkExperienceInYears between 25 to 30 has the highest ExperienceYearsInCurrentRole when the performance rating is 4.
# - The TotalWorkExperienceInYears between 30 and 40 has the highest ExperienceYearsInCurrentRole when the performance rating is 3.
# - The TotalWorkExperienceInYears between 20 to 25 has the highest ExperienceYearsInCurrentRole when the performance rating is 2.

# %% [markdown]
# **Relationship between EmpLastSalaryHikePercent and 	YearsSinceLastPromotion with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='EmpLastSalaryHikePercent',y='YearsSinceLastPromotion',hue=d1.PerformanceRating,data=d1, palette='Oranges')
plt.xlabel('EmpLastSalaryHikePercent',fontsize=20)
plt.ylabel('YearsSinceLastPromotion',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# - The EmpLastSalaryHikePercent between 22 and 24 has the highest YearsSinceLastPromotion when the performance rating is 4
# - The EmpLastSalaryHikePercent between 22 and 24 has the highest YearsSinceLastPromotion when the performance rating is 3
# - The EmpLastSalaryHikePercent between 22 and 24 has the highest YearsSinceLastPromotion when the performance rating is 2
# - The maximum YearsSinceLastPromotion is between 0 to 6 for all the performance rating

# %% [markdown]
# # Conclusion
# - By using various plots and graphs, the Exploratory data analysis was completed.
